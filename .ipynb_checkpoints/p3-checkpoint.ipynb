# %%
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv('training_dataset_V3.csv')
df.describe()
# Out:
#          Unnamed: 0          year     id_driver    num_trucks  \
# count  83414.000000  83414.000000  83414.000000  83344.000000
# mean   41706.500000   2018.960930  18222.414954     22.582921
# std    24079.692014      1.359343  11667.704926     48.829719
# min        0.000000   2015.000000     20.000000      1.000000
# 25%    20853.250000   2018.000000   7890.000000      1.000000
# 50%    41706.500000   2019.000000  16299.000000      4.000000
# 75%    62559.750000   2020.000000  28974.000000     14.000000
# max    83413.000000   2021.000000  38125.000000    195.000000
#
#        days_signup_to_approval         loads  marketplace_loads_otr  \
# count             71124.000000  83414.000000           83414.000000
# mean                298.752489      2.076270              29.477762
# std                 390.345107      2.672163              88.171940
# min                   0.000000      1.000000               0.000000
# 25%                   0.000000      1.000000               0.000000
# 50%                  61.000000      1.000000               2.000000
# 75%                 497.000000      2.000000              23.000000
# max                1653.000000    129.000000             902.000000
#
#        marketplace_loads_atlas  marketplace_loads  brokerage_loads_otr  \
# count             83414.000000       83414.000000         83414.000000
# mean                 71.579675         101.057436           148.258422
# std                 194.532776         214.502147           415.978060
# min                   0.000000           0.000000             0.000000
# 25%                   0.000000           0.000000             0.000000
# 50%                   0.000000          13.000000            15.000000
# 75%                  18.000000          94.000000           112.000000
# max                1324.000000        1348.000000          4266.000000
#
#        brokerage_loads_atlas  brokerage_loads   total_loads
# count           83414.000000     83414.000000  83414.000000
# mean               13.073021       161.331443    266.502661
# std                42.241592       413.792137    448.806175
# min                 0.000000         0.000000      1.000000
# 25%                 0.000000         5.000000     37.000000
# 50%                 0.000000        37.000000    110.000000
# 75%                 1.000000       135.000000    325.000000
# max               371.000000      4266.000000   4266.000000

# %%
def parseUniqueIds(df):
    ids = {}
    for row in df: 
        idd = row['id_driver']
        ids[idd] = [row['dt']] if idd not in ids else [ids[idd],row['dt']]
    print(ids)
    print('done')

# %%
parseUniqueIds(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-68618ff69b9d> in <module>
# ----> 1 parseUniqueIds(df)
#
# <ipython-input-19-884c3b5cfd99> in parseUniqueIds(df)
#       2     ids = {}
#       3     for row in df:
# ----> 4         idd = row['id_driver']
#       5         ids[idd] = [row['dt']] if idd not in ids else [ids[idd],row['dt']]
#       6     print(ids)
#
# TypeError: string indices must be integers
